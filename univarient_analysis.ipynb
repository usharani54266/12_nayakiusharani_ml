# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('students.csv')
df
# Out:
#        Name  Age        City
# 0      Ravi   20   Hyderabad
# 1      Sita   19      Jaipur
# 2       Ram   21       Delhi
# 3   saravni   21   hyderabad
# 4   mallika   14      gadwal
# 5   shindhu   17  wanaparthy
# 6      raju   18      mumbai
# 7     priya   19     chennai
# 8      anil   22       Delhi
# 9     rahul   18   bangalore
# 10    divya   23   ahmedabad
# 11   vikram   15      indore
# 12     neha   23      bhopal
# 13    manoj   17      gadwal
# 14   ramesh   24      nagpur
# 15    kavya   22       patna
# 16  saravni   23    warangal
# 17    rahul   22  vijayawada
# 18    meena   20       surat
# 19    kiran   19   ahmedabad
# 20      ram   24       Delhi
# 21    sneha   20        pune
# 22    pooja   18      nagpur
# 23     ajay   16       patna

# %%
df.head()
# Out:
#    Name  Age       City
# 0  Ravi   20  Hyderabad
# 1  Sita   19     Jaipur
# 2   Ram   21      Delhi

# %%
sns.countplot(df['City'])
# Out:
# <Axes: xlabel='count', ylabel='City'>

# %%
df['Name'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=5)
# Out:
# (array([2., 3., 6., 5., 8.]),
#  array([14., 16., 18., 20., 22., 24.]),
#  <BarContainer object of 5 artists>)

# %%
sns.distplot(df['Age'])
# Out:
# /tmp/ipython-input-3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].min()
# Out:
# 14

# %%
df['Age'].max()
# Out:
# 24

# %%
df['Age'].mean()
# Out:
# np.float64(19.791666666666668)

# %%
df['Age'].skew()
# Out:
# np.float64(-0.29214751759914986)
